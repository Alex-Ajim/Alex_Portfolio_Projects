# %% [markdown]
# Part 1

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Define the base URL and the directory page URL for faculty members
main_url = "https://physics.gatech.edu/people/professors"
base_url = "https://physics.gatech.edu"

# Send a GET request to the base url page and parse the HTML
response = requests.get(main_url)
soup = BeautifulSoup(response.content, 'html.parser')

## Save soup to inspect
with open('main_url_html_parser.html', 'wb') as file:  # create a file as named
  file.write(soup.prettify('utf-8')) # write a pretty version of the soup into d file wt utf encoding

# %%
# Extract links to each faculty member's profile page
faculty_links = [
    base_url + a['href'] for a in soup.select('h3.p-name a[href]')
]

# print faculty links
print(faculty_links)
# Out:
# ['https://physics.gatech.edu/user/david-ballantyne', 'https://physics.gatech.edu/user/shiladitya-banerjee', 'https://physics.gatech.edu/user/tamara-bogdanovi%C4%87', 'https://physics.gatech.edu/user/laura-cadonati', 'https://physics.gatech.edu/user/michael-chapman', 'https://physics.gatech.edu/user/jennifer-curtis', 'https://physics.gatech.edu/user/predrag-cvitanovi%C4%87', 'https://physics.gatech.edu/user/dragomir-davidovic', 'https://physics.gatech.edu/user/walter-de-heer', 'https://physics.gatech.edu/user/chunhui-du', 'https://physics.gatech.edu/user/flavio-fenton', 'https://physics.gatech.edu/user/phillip-first', 'https://physics.gatech.edu/user/daniel-goldman', 'https://physics.gatech.edu/user/roman-grigoriev', 'https://physics.gatech.edu/user/jc-gumbart', 'https://physics.gatech.edu/user/zhigang-jiang', 'https://physics.gatech.edu/user/brian-kennedy', 'https://physics.gatech.edu/user/harold-kim', 'https://physics.gatech.edu/user/itamar-kimchi', 'https://physics.gatech.edu/user/itamar-kolvin', 'https://physics.gatech.edu/user/uzi-landman', 'https://physics.gatech.edu/user/gongjie-li', 'https://physics.gatech.edu/user/zhu-xi-luo', 'https://physics.gatech.edu/user/martin-maldovan', 'https://physics.gatech.edu/user/elisabetta-matsumoto', 'https://physics.gatech.edu/user/martin-mourigal', 'https://physics.gatech.edu/user/a.-nepomuk-otte', 'https://physics.gatech.edu/user/feryal-%C3%B6zel', 'https://physics.gatech.edu/user/colin-parker', 'https://physics.gatech.edu/user/dimitrios-psaltis', 'https://physics.gatech.edu/user/michael-pustilnik', 'https://physics.gatech.edu/user/chandra-raman', 'https://physics.gatech.edu/user/d.--zeb-rocklin', 'https://physics.gatech.edu/user/carlos-sa-de-melo', 'https://physics.gatech.edu/user/surabhi-sachdev', 'https://physics.gatech.edu/user/michael-schatz', 'https://physics.gatech.edu/user/audrey-sederberg', 'https://physics.gatech.edu/user/simon-sponberg', 'https://physics.gatech.edu/user/ignacio-taboada', 'https://physics.gatech.edu/user/rick-trebino', 'https://physics.gatech.edu/user/hailong-wang', 'https://physics.gatech.edu/user/xueda-wen', 'https://physics.gatech.edu/user/kurt-wiesenfeld', 'https://physics.gatech.edu/user/john-wise', 'https://physics.gatech.edu/user/peter-yunker', 'https://physics.gatech.edu/user/andrew-zangwill']

# %%
# Extract the names of the faculty members
names = [a.get_text(strip=True) for a in soup.select('h3.p-name a')]

# print names
print(names)
# Out:
# ['David Ballantyne', 'Shiladitya Banerjee', 'Tamara Bogdanović', 'Laura Cadonati', 'Michael Chapman', 'Jennifer Curtis', 'Predrag Cvitanović', 'Dragomir Davidovic', 'Walter de Heer', 'Chunhui Rita Du', 'Flavio Fenton', 'Phillip First', 'Daniel Goldman', 'Roman Grigoriev', 'JC Gumbart', 'Zhigang Jiang', 'Brian Kennedy', 'Harold Kim', 'Itamar Kimchi', 'Itamar Kolvin', 'Uzi Landman', 'Gongjie Li', 'Zhu-Xi Luo', 'Martin Maldovan', 'Elisabetta Matsumoto', 'Martin Mourigal', 'A. Nepomuk Otte', 'Feryal Özel', 'Colin V Parker', 'Dimitrios Psaltis', 'Michael Pustilnik', 'Chandra Raman', 'D.  Zeb Rocklin', 'Carlos Sa de Melo', 'Surabhi Sachdev', 'Michael Schatz', 'Audrey Sederberg', 'Simon Sponberg', 'Ignacio Taboada', 'Rick Trebino', 'Hailong Wang', 'Xueda Wen', 'Kurt Wiesenfeld', 'John Wise', 'Peter Yunker', 'Andrew Zangwill']

# %%
# faculty_response = requests.get("https://physics.gatech.edu/user/david-ballantyne")
# faculty_soup = BeautifulSoup(faculty_response.content, 'html.parser')

# ## Save soup to inspect
# with open('faculty_url_html_parser.html', 'wb') as file:  # create a file as named
#   file.write(faculty_soup.prettify('utf-8')) # write a pretty version of the soup into d file wt utf encoding

# %%
import time

# Define a function to retrieve the research information of each faculty member given their URL
def get_research(faculty_link):
    try:
        # Make a GET request to the faculty profile page and parse the response
        faculty_response = requests.get(faculty_link)
        faculty_soup = BeautifulSoup(faculty_response.content, 'html.parser')

        # Find the research header and retrieve the text in the following <p> tags
        research_section = faculty_soup.find('h3', string="Research")
        if research_section:
            research_texts = [p.get_text(strip=True) for p in research_section.find_next_siblings('p')]
            research = ' '.join(research_texts)
        else:
            research = "Research information not found"

        # Slow down to avoid overwhelming the server
        time.sleep(1)

        return research

    except requests.exceptions.RequestException as e:
        return "Error retrieving research information"

# Retrieve the research information for each faculty member
research_texts = [get_research(link) for link in faculty_links]

print(research_texts)
# Out:
# ['high-energy astrophysics; accretion disks; galaxy and black hole evolution My research concentrates on topics in high-energy astrophysics with an emphasis on interpreting existing data and making predictions for future observations. My main interests are: (i) the evolution of galaxies and their central supermassive black holes and (ii) the physics of accretion disks around both black holes and neutron stars. My work often involves comparing computer based models with published data from X-ray, radio and/or infrared telescopes. All of these directions are guided by my underlying research philosophy of using any necessary tool or technique, unlimited by wavelength range or physical process, to make progress in understanding the relevant physics. Students working with me will be exposed to a wide range of astrophysical processes and theories, but will also learn to respect and be guided by observational constraints. Papers Since Arriving at Georgia Tech  ', 'Physics of Living Systems: Cell and Tissue mechanics, Collective cell dynamics, Cytoskeletal dynamics, Bacterial physiology, Learning and adaptation. seeGoogle Scholar Page', 'My research interests are in astrophysics of some of the most massive black holes in the universe, a.k.a.,supermassive black holes. Within my group we investigate the physical processes that arise in accretion flows around supermassive black holes and use them as luminous tracers of these otherwise dark objects. Some of the scenarios we study include the accretion of gas by the single and binary supermassive black holes as well as the accretion of stars that happen to be disrupted by the black hole tides in galactic nuclei. My goal as a theorist is to predict the signatures of these interactions which can be searched for in observations, as well as to provide interpretation for some of the puzzling astrophysical events seen on the sky. In a nutshell, my research interest include: Publication list via NASA\xa0Astrophysics Data System', 'I joined the Center for Relativistic Astrophysics at GeorgiaTech in January 2015, from the University of Massachusetts Amherst. My principal research interests is gravitational wave astrophysics and LIGO – I have been a member of the LIGO Scientific Collaboration since 2002. I am also interested in particle astrophysics; I have been a member of the Borexino Collaboration (solar neutrino detection) until 2013 and the DarkSide Collaboration (direct dark matter search) until 2014. [Publication list]', 'Contemporary quantum mechanics, manipulating the quantum behavior of single atoms and photons', 'Cell biophysics. Cell mechanics of adhesion, migration and dynamics. Immunophysics and immunoengineering. Hyaluronan glycobiology. Hyaluronan synthase.\xa0Physics of tissues. For a detailed overview, visit ourgroup website. Frustrated\xa0phagocytosis\xa0in\xa0J774\xa0macrophages ends in distinct non-muscle myosin II contraction. D.T. Kovari, W. Wei, R. Fogg, J.-S. Toro, J.E. Curtis,under review. Cell surface access is modulated by tethered\xa0bottlebrushproteoglycans.P.S. Chang, L.T. McLane, R. Fogg, J. Scrimgeour, J.S. Temenoff, A. Granqvist, J.E. Curtis,under review. Nanopatterning reconfigurable magnetic landscapes via thermally assisted scanning probe lithography. E.\xa0Albisetti, D.\xa0Petti, M.\xa0Pancaldi, M.\xa0Madami, S.\xa0Tacchi,\xa0J.E. Curtis, W. P. King, A.\xa0Papp, G.\xa0Csaba, W.\xa0Porod, P.\xa0Vavassori\xa0E.\xa0Riedo\xa0and R.\xa0Bertacco,\u200bNature Nano.DOI:10.1038/NNANO.2016.25 (2016). Beads on a string: Structure of bound aggregates of globular particles and long polymer chains. A.\xa0Souslov, J.E. Curtis, P.M.\xa0Goldbart,Soft Matter, 11, 8092-8099 (2015). Speed dependence of thermochemical nanolithography for grey scale patterning. K.M. Carroll, M.\xa0Desai, A. Giordano, W.P. King, E.\xa0Riedo, J.E. Curtis,ChemPhysChem15(12), 2530-2535 (2014). Heparin coating for controlled biomolecule presentation to mesenchymal stem cell spheroids.\xa0J. Lei, L.T.\xa0M ...

# %%
# Combine names, links, and research information into a DataFrame
d1 = pd.DataFrame({
    "Name": names,
    "Profile URL": faculty_links,
    "Research": research_texts
})

# Display the DataFrame
d1.head()
# Out:
#                   Name                                        Profile URL  \
# 0     David Ballantyne   https://physics.gatech.edu/user/david-ballantyne
# 1  Shiladitya Banerjee  https://physics.gatech.edu/user/shiladitya-ban...
# 2    Tamara Bogdanović  https://physics.gatech.edu/user/tamara-bogdano...
# 3       Laura Cadonati     https://physics.gatech.edu/user/laura-cadonati
# 4      Michael Chapman    https://physics.gatech.edu/user/michael-chapman
#
#                                             Research
# 0  high-energy astrophysics; accretion disks; gal...
# 1  Physics of Living Systems: Cell and Tissue mec...
# 2  My research interests are in astrophysics of s...
# 3  I joined the Center for Relativistic Astrophys...
# 4  Contemporary quantum mechanics, manipulating t...
